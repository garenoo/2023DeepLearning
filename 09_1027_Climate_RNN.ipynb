# %%
import numpy as np
from numpy import mean
from numpy import std
from numpy import dstack
from numpy import array
from scipy.stats import mode
from scipy.interpolate import interp1d

import pandas as pd
from pandas import read_csv
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from keras.models import Model
from tensorflow.keras.optimizers import Adam

from sklearn.preprocessing import LabelEncoder
import keras
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Activation
from keras.layers import SimpleRNN
from keras.layers import Conv1D, MaxPooling1D, Dense, Input, Dropout, Flatten, BatchNormalization
from keras.layers import concatenate, Dropout
from keras.utils import to_categorical
from keras import optimizers
import seaborn as sns

# %%
df = pd.read_csv('DailyDelhiClimateTrain.csv')

# %%
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df.shape
# Out:
# (1462, 5)

# %%
def MinMaxScaler(data):
    numerator = data - np.min(data, 0)
    denominator = np.max(data, 0) - np.min(data, 0)

    return numerator / (denominator + 1e-7)

# %%
dfx = df[['meantemp', 'humidity', 'wind_speed', 'meanpressure']]
dfx = MinMaxScaler(dfx)

dfy = dfx[['meantemp']]
dfx = dfx[['humidity', 'wind_speed', 'meanpressure']]

dfx
# Out:
#       humidity  wind_speed  meanpressure
# 0     0.820957    0.000000      0.132603
# 1     0.907591    0.070583      0.132881
# 2     0.849835    0.109743      0.132994
# 3     0.668867    0.029212      0.132799
# 4     0.847910    0.087636      0.132712
# ...        ...         ...           ...
# 1457  0.630865    0.084032      0.132590
# 1458  0.859736    0.142113      0.132764
# 1459  0.880638    0.148429      0.132895
# 1460  0.849835    0.173496      0.132660
# 1461  1.000000    0.000000      0.132647
#
# [1462 rows x 3 columns]

# %%
dfx.describe()
# Out:
#           humidity   wind_speed  meanpressure
# count  1462.000000  1462.000000   1462.000000
# mean      0.546868     0.161113      0.132009
# std       0.193709     0.108044      0.023460
# min       0.000000     0.000000      0.000000
# 25%       0.426774     0.082307      0.130770
# 50%       0.568276     0.147363      0.131679
# 75%       0.679094     0.218812      0.132509
# max       1.000000     1.000000      1.000000

# %%
dfy.head()
# Out:
#    meantemp
# 0  0.122271
# 1  0.042795
# 2  0.035662
# 3  0.081514
# 4  0.000000

# %%
time_step = 40
step = 10

def create_dataset(X, y, time_step, step):
    Xs, ys = [], []

    for i in range(0, len(X) - time_step, step):
        v = X.iloc[i : (i + time_step)].values
        labels = y.iloc[i + time_step]

        Xs.append(v)
        ys.append(labels)

    return np.array(Xs), np.array(ys)

# %%
X, y = create_dataset(dfx, dfy, time_step, step)

X.shape
# Out:
# (143, 40, 3)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((95, 40, 3), (48, 40, 3), (95, 1), (48, 1))

# %%
model = Sequential([
    SimpleRNN(20, activation='relu', input_shape=(X.shape[1:]), return_sequences=True),
    Dropout(0.5),
    SimpleRNN(20, activation='relu'),
    Dropout(0.3),
    Dense(1)
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 40, 20)            480
#
#  dropout (Dropout)           (None, 40, 20)            0
#
#  simple_rnn_1 (SimpleRNN)    (None, 20)                820
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense (Dense)               (None, 1)                 21
#
# =================================================================
# Total params: 1321 (5.16 KB)
# Trainable params: 1321 (5.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam')

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.33, shuffle=False)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 2s 391ms/step - loss: 0.2585 - val_loss: 0.2174
# Epoch 2/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.2512 - val_loss: 0.2028
# Epoch 3/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.2113 - val_loss: 0.1870
# Epoch 4/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.2048 - val_loss: 0.1711
# Epoch 5/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1887 - val_loss: 0.1534
# Epoch 6/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2011 - val_loss: 0.1372
# Epoch 7/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1778 - val_loss: 0.1227
# Epoch 8/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1774 - val_loss: 0.1114
# Epoch 9/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1696 - val_loss: 0.1024
# Epoch 10/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1672 - val_loss: 0.0962
# Epoch 11/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1415 - val_loss: 0.0910
# Epoch 12/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1312 - val_loss: 0.0865
# Epoch 13/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1460 - val_loss: 0.0832
# Epoch 14/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1859 - val_loss: 0.0805
# Epoch 15/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1207 - val_loss: 0.0788
# Epoch 16/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1024 - val_loss: 0.0761
# Epoch 17/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1118 - val_loss: 0.0730
# Epoch 18/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1482 - val_loss: 0.0705
# Epoch 19/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1452 - val_loss: 0.0686
# Epoch 20/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0943 - val_loss: 0.0668
# Epoch 21/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1859 - val_loss: 0.0664
# Epoch 22/100
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1562 - val_loss: 0.0682
# Epoch 23/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1064 - val_loss: 0.0700
# Epoch 24/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1300 - val_loss: 0.0714
# Epoch 25/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1461 - val_loss: 0.0725
# Epoch 26/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1194 - val_loss: 0.0721
# Epoch 27/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0990 - val_loss: 0.0704
# Epoch 28/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1425 - val_loss: 0.0683
# Epoch 29/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1202 - val_loss: 0.0671
# Epoch 30/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1014 - val_loss: 0.0650
# Epoch 31/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1133 - val_loss: 0.0628
# Epoch 32/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1228 - val_loss: 0.0613
# Epoch 33/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1134 - val_loss: 0.0605
# Epoch 34/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0813 - val_loss: 0.0603
# Epoch 35/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0972 - val_loss: 0.0595
# Epoch 36/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0918 - val_loss: 0.0593
# Epoch 37/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0984 - val_loss: 0.0603
# Epoch 38/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1206 - val_loss: 0.0599
# Epoch 39/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1200 - val_loss: 0.0589
# Epoch 40/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0825 - val_loss: 0.0582
# Epoch 41/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1327 - val_loss: 0.0583
# Epoch 42/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0630 - val_loss: 0.0583
# Epoch 43/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0941 - val_loss: 0.0571
# Epoch 44/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0704 - val_loss: 0.0558
# Epoch 45/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1179 - val_loss: 0.0555
# Epoch 46/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0840 - val_loss: 0.0553
# Epoch 47/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0879 - val_loss: 0.0553
# Epoch 48/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0857 - val_loss: 0.0539
# Epoch 49/100
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0897 - val_loss: 0.0531
# Epoch 50/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0953 - val_loss: 0.0521
# Epoch 51/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0845 - val_loss: 0.0520
# Epoch 52/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0875 - val_loss: 0.0520
# Epoch 53/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0989 - val_loss: 0.0503
# Epoch 54/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1038 - val_loss: 0.0494
# Epoch 55/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0741 - val_loss: 0.0484
# Epoch 56/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0908 - val_loss: 0.0481
# Epoch 57/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0744 - val_loss: 0.0488
# Epoch 58/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0901 - val_loss: 0.0493
# Epoch 59/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0658 - val_loss: 0.0495
# Epoch 60/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0728 - val_loss: 0.0490
# Epoch 61/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0951 - val_loss: 0.0484
# Epoch 62/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0801 - val_loss: 0.0480
# Epoch 63/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0886 - val_loss: 0.0476
# Epoch 64/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0821 - val_loss: 0.0474
# Epoch 65/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0676 - val_loss: 0.0465
# Epoch 66/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0815 - val_loss: 0.0457
# Epoch 67/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1001 - val_loss: 0.0451
# Epoch 68/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0548 - val_loss: 0.0449
# Epoch 69/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0722 - val_loss: 0.0449
# Epoch 70/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0547 - val_loss: 0.0437
# Epoch 71/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0590 - val_loss: 0.0421
# Epoch 72/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0646 - val_loss: 0.0409
# Epoch 73/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0754 - val_loss: 0.0410
# Epoch 74/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0748 - val_loss: 0.0426
# Epoch 75/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0458 - val_loss: 0.0463
# Epoch 76/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0628 - val_loss: 0.0483
# Epoch 77/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0694 - val_loss: 0.0481
# Epoch 78/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0726 - val_loss: 0.0470
# Epoch 79/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0588 - val_loss: 0.0458
# Epoch 80/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0674 - val_loss: 0.0438
# Epoch 81/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0699 - val_loss: 0.0424
# Epoch 82/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0597 - val_loss: 0.0416
# Epoch 83/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0718 - val_loss: 0.0418
# Epoch 84/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0658 - val_loss: 0.0416
# Epoch 85/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0613 - val_loss: 0.0412
# Epoch 86/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0614 - val_loss: 0.0406
# Epoch 87/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0604 - val_loss: 0.0414
# Epoch 88/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0662 - val_loss: 0.0428
# Epoch 89/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0476 - val_loss: 0.0422
# Epoch 90/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0617 - val_loss: 0.0414
# Epoch 91/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0664 - val_loss: 0.0403
# Epoch 92/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0784 - val_loss: 0.0398
# Epoch 93/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0590 - val_loss: 0.0391
# Epoch 94/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0501 - val_loss: 0.0395
# Epoch 95/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0466 - val_loss: 0.0412
# Epoch 96/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0547 - val_loss: 0.0428
# Epoch 97/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0590 - val_loss: 0.0439
# Epoch 98/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0555 - val_loss: 0.0427
# Epoch 99/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0677 - val_loss: 0.0412
# Epoch 100/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0828 - val_loss: 0.0400

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

x = np.arange(0, len(history.history['loss']))

plt.plot(x, loss, 'y', label='loss')
plt.plot(x, val_loss, 'r', label='val loss')
plt.title('Losses')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 10ms/step

# %%
y_pred.shape

plt.plot(y_test, color='red', label='real meantemp')
plt.plot(y_pred, color='blue', label='predicted meantemp')
plt.title('meantemp prediction')
plt.xlabel('time')
plt.ylabel('meantemp price')
plt.legend()
plt.show()
